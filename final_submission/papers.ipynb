# %%
# !pip install arxiv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 3.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=4c5358575f2780b9bbc4203a0a18b19112bf3c566f006c63873013c3f53d7251
#   Stored in directory: /root/.cache/pip/wheels/83/63/2f/117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built sgmllib3k
# ...

# %%
import arxiv

# %%
import http.client
http.client.HTTPConnection._http_vsn = 10
http.client.HTTPConnection._http_vsn_str = 'HTTP/1.0'

# %%
arxiv.Search()
# Out:
# arxiv.Search(query='', id_list=[], max_results=inf, sort_by=<SortCriterion.Relevance: 'relevance'>, sort_order=<SortOrder.Descending: 'descending'>)

# %%
search = arxiv.Search(
  query = "speech",
  max_results = 1000,
  sort_by = arxiv.SortCriterion.SubmittedDate
)

# %%
text_file = open('title.txt', 'w')

for result in search.results():
    text_file.write(result.title)
    text_file.write('\n')
text_file.close()

# %%
search = arxiv.Search(id_list=["1605.08386v1"])
paper = next(search.results())
print(paper.title)
# Out:
# Heat-bath random walks with Markov bases

# %%
# !pip install semanticscholar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import pandas as pd

# %%
import urllib3, socket
from urllib3.connection import HTTPConnection
    
HTTPConnection.default_socket_options = ( 
    HTTPConnection.default_socket_options + [
    (socket.SOL_SOCKET, socket.SO_SNDBUF, 100000000), #100MB in byte
    (socket.SOL_SOCKET, socket.SO_RCVBUF, 100000000)
])

# %%
from semanticscholar import SemanticScholar
s2_api_key = '6GT8zqfnyi1p2rlbZ4wvQHm7NCMcUBL3hTahHF4e'
sch = SemanticScholar(api_key=s2_api_key)
results = sch.search_paper('speech', year='2023')
# for i in range(len(results)):
#      print(results.next_page()[i].title)
# for item in results:
#      print(item.title)
all_data = []
for item in results:
    temp = ["","",[],"","","","","","","","",""]
    temp[0] = item['title']
    for i in range(len(item['authors'])):
        temp[1] += item['authors'][i]['name']
        temp[1] += ", "
        temp[2].append(item['authors'][i]['authorId'])
    temp[1] = temp[1][:len(temp[1])-1]
    # lst = temp[2]
    # authorInfo = sch.get_authors(lst)
    # temp[3] = authorInfo[0]['paperCount']
    # temp[4] = authorInfo[0]['citationCount']
    temp[5] = item['publicationDate']
    temp[6] = item['abstract']
    temp[7] = item['referenceCount']
    temp[8] = item['citationCount']
    temp[9] = item['influentialCitationCount']
    temp[10] = item['venue']
    temp[11] = item['fieldsOfStudy']
    #temp[12] = item['externalIds']['DOI']
    all_data.append(temp)

column_names = ['Title','Author Name','Author Id','1st Author Paper Count','1st Author Citation Count','Date','Abstract','Paper Reference Count','Paper Citation Count','Influential Citation Count','Venue', 'Fields Of Study']
df5 = pd.DataFrame(all_data, columns=column_names)
df5
# Out:
#                                                   Title  \
# 0     Neural Codec Language Models are Zero-Shot Tex...
# 1     TAPLoss: A Temporal Acoustic Parameter Loss fo...
# 2     New threats to society from free-speech social...
# 3     Spread the Word: Enhancing Replicability of Sp...
# 4     Speech-Encoding Deficits in Neonates Born Larg...
# ...                                                 ...
# 2272  Морфосинтаксические особенности русского языка...
# 2273  The Problem of Variability in Biblical Phraseo...
# 2274  ASTMH – A Means to What End?The Nexus of Tropi...
# 2275  Harmonization of Communication of the Intervie...
# 2276  “Arzamas Code” and V. A. Zhukovsky’s Creative ...
#
#                                             Author Name  \
# 0     Chengyi Wang, Sanyuan Chen, Yu Wu, Zi-Hua Zhan...
# 1     Yunyang Zeng, Joseph Konan, Shuo Han, David Bi...
# 2       Dominik Bär, Nicolas Pröllochs, S. Feuerriegel,
# 3                            Julia F. Strand, V. Brown,
# ...

# %%
df2
# Out:
#                                                   Title  \
# 0     wav2vec 2.0: A Framework for Self-Supervised L...
# 1     Conformer: Convolution-augmented Transformer f...
# 2     HiFi-GAN: Generative Adversarial Networks for ...
# 3     FastSpeech 2: Fast and High-Quality End-to-End...
# 4     The airborne lifetime of small speech droplets...
# ...                                                 ...
# 9994  Perception of speech stress in children with h...
# 9995  Machine Learning Algorithms for Detection of P...
# 9996  Speech Acts: Is Racial Vilification a Form of ...
# 9997  SPEECH ACTS AND ACTIONS IN LEGAL LANGUAGE: CON...
# 9998             Context-Based Quotation Recommendation
#
#                                             Author Name  \
# 0     Alexei Baevski, Henry Zhou, Abdel-rahman Moham...
# 1     Anmol Gulati, James Qin, C. Chiu, Niki Parmar,...
# 2             Jungil Kong, Jaehyeon Kim, Jaekyoung Bae,
# 3     Yi Ren, Chenxu Hu, Xu Tan, Tao Qin, Sheng Zhao...
# ...

# %%
df3
# Out:
#                                                   Title  \
# 0     HuBERT: Self-Supervised Speech Representation ...
# 1     WavLM: Large-Scale Self-Supervised Pre-Trainin...
# 2     SUPERB: Speech processing Universal PERformanc...
# 3         SpeechBrain: A General-Purpose Speech Toolkit
# 4     Conditional Variational Autoencoder with Adver...
# ...                                                 ...
# 9994  The impact of radical parotidectomy with immed...
# 9995  Automatically Detecting Cyberbullying Comments...
# 9996  Mental Simulations of Phonological Representat...
# 9997  Oral health status of hearing and speech-impai...
# 9998  Communication Strategies of Warning in Novel J...
#
#                                             Author Name  \
# 0     Wei-Ning Hsu, Benjamin Bolte, Yao-Hung Hubert ...
# 1     Sanyuan Chen, Chengyi Wang, Zhengyang Chen, Yu...
# 2     Shu-wen Yang, Po-Han Chi, Yung-Sung Chuang, Ch...
# 3     M. Ravanelli, Titouan Parcollet, Peter William...
# ...

# %%
df4
# Out:
#                                                   Title  \
# 0     data2vec: A General Framework for Self-supervi...
# 1     Overview of the HASOC Subtrack at FIRE 2022: H...
# 2     Learning Audio-Visual Speech Representation by...
# 3     Robust Speech Recognition via Large-Scale Weak...
# 4     mSLAM: Massively multilingual joint pre-traini...
# ...                                                 ...
# 9994  Supporting adjective learning by children with...
# 9995  Emotional and Rational Frames Contained in Ins...
# 9996  RNN with Improved Temporal Modeling for Speech...
# 9997  Hearing Impairment With Cognitive Decline Incr...
# 9998  Using Contested Narratives to Negotiate Free S...
#
#                                             Author Name  \
# 0     Alexei Baevski, Wei-Ning Hsu, Qiantong Xu, Aru...
# 1     Thomas Mandl, Sandip J Modha, Gautam Kishore S...
# 2     Bowen Shi, Wei-Ning Hsu, Kushal Lakhotia, Abde...
# 3     Alec Radford, Jong Wook Kim, Tao Xu, Greg Broc...
# ...

# %%
df5
# Out:
#                                                   Title  \
# 0     Neural Codec Language Models are Zero-Shot Tex...
# 1     TAPLoss: A Temporal Acoustic Parameter Loss fo...
# 2     New threats to society from free-speech social...
# 3     Spread the Word: Enhancing Replicability of Sp...
# 4     Speech-Encoding Deficits in Neonates Born Larg...
# ...                                                 ...
# 2272  Морфосинтаксические особенности русского языка...
# 2273  The Problem of Variability in Biblical Phraseo...
# 2274  ASTMH – A Means to What End?The Nexus of Tropi...
# 2275  Harmonization of Communication of the Intervie...
# 2276  “Arzamas Code” and V. A. Zhukovsky’s Creative ...
#
#                                             Author Name  \
# 0     Chengyi Wang, Sanyuan Chen, Yu Wu, Zi-Hua Zhan...
# 1     Yunyang Zeng, Joseph Konan, Shuo Han, David Bi...
# 2       Dominik Bär, Nicolas Pröllochs, S. Feuerriegel,
# 3                            Julia F. Strand, V. Brown,
# ...

# %%
data = pd.concat([df2, df3, df4, df5], ignore_index=True)

# %%
data
# Out:
#                                                    Title  \
# 0      wav2vec 2.0: A Framework for Self-Supervised L...
# 1      Conformer: Convolution-augmented Transformer f...
# 2      HiFi-GAN: Generative Adversarial Networks for ...
# 3      FastSpeech 2: Fast and High-Quality End-to-End...
# 4      The airborne lifetime of small speech droplets...
# ...                                                  ...
# 32269  Морфосинтаксические особенности русского языка...
# 32270  The Problem of Variability in Biblical Phraseo...
# 32271  ASTMH – A Means to What End?The Nexus of Tropi...
# 32272  Harmonization of Communication of the Intervie...
# 32273  “Arzamas Code” and V. A. Zhukovsky’s Creative ...
#
#                                              Author Name  \
# 0      Alexei Baevski, Henry Zhou, Abdel-rahman Moham...
# 1      Anmol Gulati, James Qin, C. Chiu, Niki Parmar,...
# 2              Jungil Kong, Jaehyeon Kim, Jaekyoung Bae,
# ...

# %%
df.to_csv('result2.csv', index = False)

# %%
data1 = pd.read_csv('result.csv')

# %%
data2 = pd.read_csv('result2.csv')

# %%
df = pd.concat([data1, data2], ignore_index=True)

# %%
df
# Out:
#                                                    Title  \
# 0      wav2vec 2.0: A Framework for Self-Supervised L...
# 1      data2vec: A General Framework for Self-supervi...
# 2      HuBERT: Self-Supervised Speech Representation ...
# 3      WavLM: Large-Scale Self-Supervised Pre-Trainin...
# 4      SUPERB: Speech processing Universal PERformanc...
# ...                                                  ...
# 19993              The Portuguese Policy Agendas Project
# 19994  Morphosyntactic Development and Severe Parenta...
# 19995  Can Orofacial Structures Affect Tooth Morphology?
# 19996  The Place and History of the Activities of Kaz...
# 19997  Simplifying Deep Neural Networks for FPGA-Like...
#
#                                              Author Name  \
# 0      Alexei Baevski, Henry Zhou, Abdel-rahman Moham...
# 1      Alexei Baevski, Wei-Ning Hsu, Qiantong Xu, Aru...
# 2      Wei-Ning Hsu, Benjamin Bolte, Yao-Hung Hubert ...
# ...

# %%
df['Author Id'][0][1]
# Out:
# "'"

# %%
sch.timeout = 20
for i in range(2000):
  if(len(data['Author Id'][i]) > 0 ):
    if(type(data['Author Id'][i][0]) == str ):
      id = int(data['Author Id'][i][0])
      results = sch.get_author(id)
      data['1st Author Paper Count'][i] = results['paperCount']
      data['1st Author Citation Count'][i] = results['citationCount']
# Out:
# <ipython-input-75-8cd668cb008a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['1st Author Paper Count'][i] = results['paperCount']
# <ipython-input-75-8cd668cb008a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['1st Author Citation Count'][i] = results['citationCount']

# %%
sch.timeout = 20
for i in range(60):
  if(len(data['Author Id'][i+5941]) > 0 ):
    if(type(data['Author Id'][i+5941][0]) == str ):
      id = int(data['Author Id'][i+5941][0])
      results = sch.get_author(id)
      data['1st Author Paper Count'][i+5941] = results['paperCount']
      data['1st Author Citation Count'][i+5941] = results['citationCount']
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-110-ca39fa6b9ac6> in <module>
#       4     if(type(data['Author Id'][i+5941][0]) == str ):
#       5       id = int(data['Author Id'][i+5941][0])
# ----> 6       results = sch.get_author(id)
#       7       data['1st Author Paper Count'][i+5941] = results['paperCount']
#       8       data['1st Author Citation Count'][i+5941] = results['citationCount']
#
# /usr/local/lib/python3.8/dist-packages/semanticscholar/SemanticScholar.py in get_author(self, author_id, fields)
#     368         parameters = f'&fields={fields}'
#     369
# --> 370         data = self._requester.get_data(url, parameters, self.auth_header)
#     371         author = Author(data)
#     372
#
# /usr/local/lib/python3.8/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
# ...

# %%
data
# Out:
#                                                    Title  \
# 0      wav2vec 2.0: A Framework for Self-Supervised L...
# 1      Conformer: Convolution-augmented Transformer f...
# 2      HiFi-GAN: Generative Adversarial Networks for ...
# 3      FastSpeech 2: Fast and High-Quality End-to-End...
# 4      The airborne lifetime of small speech droplets...
# ...                                                  ...
# 32269  Морфосинтаксические особенности русского языка...
# 32270  The Problem of Variability in Biblical Phraseo...
# 32271  ASTMH – A Means to What End?The Nexus of Tropi...
# 32272  Harmonization of Communication of the Intervie...
# 32273  “Arzamas Code” and V. A. Zhukovsky’s Creative ...
#
#                                              Author Name  \
# 0      Alexei Baevski, Henry Zhou, Abdel-rahman Moham...
# 1      Anmol Gulati, James Qin, C. Chiu, Niki Parmar,...
# 2              Jungil Kong, Jaehyeon Kim, Jaekyoung Bae,
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data['1st Author Paper Count'][5940]
# Out:
# 22

# %%
data['Author Id'][5941]
# Out:
# ['115523134', '51183518', '3581989']

# %%
data.to_csv('result4.csv', index = False)

# %%
df['1st Author Paper Count'][734]
# Out:
# ''

# %%
import types

# %%
df['Author Id'][9998][0] is str
# Out:
# False

# %%
int(df['Author Id'][0][0])
# Out:
# 1753223

# %%
results.next_page()

# %%
all_data = []
for item in results.items.next_page():
    temp = ["","",[],"","","","","","","","",""]
    temp[0] = item['title']
    for i in range(len(item['authors'])):
        temp[1] += item['authors'][i]['name']
        temp[1] += ", "
        temp[2].append(item['authors'][i]['authorId'])
    temp[1] = temp[1][:len(temp[1])-1]
    # lst = temp[2]
    # authorInfo = sch.get_authors(lst)
    # temp[3] = authorInfo[0]['paperCount']
    # temp[4] = authorInfo[0]['citationCount']
    temp[5] = item['publicationDate']
    temp[6] = item['abstract']
    temp[7] = item['referenceCount']
    temp[8] = item['citationCount']
    temp[9] = item['influentialCitationCount']
    temp[10] = item['venue']
    temp[11] = item['fieldsOfStudy']
    #temp[10] = item['externalIds']['DOI']
    all_data.append(temp)

column_names = ['Title','Author Name','Author Id','1st Author Paper Count','1st Author Citation Count','Date','Abstract','Paper Reference Count','Paper Citation Count','Influential Citation Count','Venue', 'Fields Of Study']
df = pd.DataFrame(all_data, columns=column_names)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-c412f7da5052> in <module>
#       1 all_data = []
# ----> 2 for item in results.items.next_page():
#       3     temp = ["","",[],"","","","","","","","",""]
#       4     temp[0] = item['title']
#       5     for i in range(len(item['authors'])):
#
# AttributeError: 'list' object has no attribute 'next_page'

# %%
import pandas as pd

# %%
data = pd.read_csv('result4.csv')
data
# Out:
#                                                    Title  \
# 0      wav2vec 2.0: A Framework for Self-Supervised L...
# 1      Conformer: Convolution-augmented Transformer f...
# 2      HiFi-GAN: Generative Adversarial Networks for ...
# 3      FastSpeech 2: Fast and High-Quality End-to-End...
# 4      The airborne lifetime of small speech droplets...
# ...                                                  ...
# 32269  Морфосинтаксические особенности русского языка...
# 32270  The Problem of Variability in Biblical Phraseo...
# 32271  ASTMH – A Means to What End?The Nexus of Tropi...
# 32272  Harmonization of Communication of the Intervie...
# 32273  “Arzamas Code” and V. A. Zhukovsky’s Creative ...
#
#                                              Author Name  \
# 0      Alexei Baevski, Henry Zhou, Abdel-rahman Moham...
# 1      Anmol Gulati, James Qin, C. Chiu, Niki Parmar,...
# 2              Jungil Kong, Jaehyeon Kim, Jaekyoung Bae,
# ...

# %%
data[data['Paper Citation Count']>1]
# Out:
#                                                    Title  \
# 0      wav2vec 2.0: A Framework for Self-Supervised L...
# 1      Conformer: Convolution-augmented Transformer f...
# 2      HiFi-GAN: Generative Adversarial Networks for ...
# 3      FastSpeech 2: Fast and High-Quality End-to-End...
# 4      The airborne lifetime of small speech droplets...
# ...                                                  ...
# 30602  Exploring individual differences in musical rh...
# 30603  Deep Learning-Based Cost-Effective and Respons...
# 30604  Scaling Laws for Generative Mixed-Modal Langua...
# 30971               Sequence Labeling With Meta-Learning
# 30972  Comparing autism phenotypes in children born e...
#
#                                              Author Name  \
# 0      Alexei Baevski, Henry Zhou, Abdel-rahman Moham...
# 1      Anmol Gulati, James Qin, C. Chiu, Niki Parmar,...
# 2              Jungil Kong, Jaehyeon Kim, Jaekyoung Bae,
# ...
