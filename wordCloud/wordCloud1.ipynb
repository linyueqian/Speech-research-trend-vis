# %%
import dash
import dash_html_components as html
#import wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import base64
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/ts/yc6c7tl96hjdf33yyy_9y96m0000gn/T/ipykernel_40371/2886550293.py in <module>
# ----> 1 import dash
#       2 import dash_html_components as html
#       3 #import wordcloud
#       4 from wordcloud import WordCloud
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'dash'

# %%
conda install dash
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/osx-64::daal4py==2021.3.0=py39h01d92e1_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/osx-64::bottleneck==1.3.2=py39he3068b8_1
#   - defaults/osx-64::mkl_random==1.2.2=py39hb2f4e1b_0
#   - defaults/osx-64::patsy==0.5.2=py39hecd8cb5_0
#   - defaults/osx-64::imagecodecs==2021.8.26=py39ha952a84_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib-base==3.4.3=py39h0a11d32_0
#   - defaults/osx-64::numpy==1.20.3=py39h4b4dc7a_0
#   - defaults/osx-64::pywavelets==1.1.1=py39he3068b8_4
#   - defaults/osx-64::scikit-learn-intelex==2021.3.0=py39hecd8cb5_0
#   - defaults/osx-64::h5py==3.2.1=py39h90fc2a2_0
#   - defaults/osx-64::numba==0.55.1=py39hae1ba45_0
#   - defaults/osx-64::pytables==3.6.1=py39h648f197_1
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/osx-64::pandas==1.4.4=py39he9d5cce_0
#   - defaults/osx-64::pyerfa==2.0.0=py39h9ed2024_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/osx-64::numexpr==2.7.3=py39h5873af2_1
#   - defaults/osx-64::mkl_fft==1.3.1=py39h4ab4a9b_0
#   - defaults/osx-64::astropy==5.1=py39h67323c0_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::_anaconda_depends==2021.11=py39_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda==custom=py39_1
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/shenxingyu/opt/anaconda3
#
#   added / updated specs:
#     - dash
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |   py39he9d5cce_7         354 KB
#     ca-certificates-2023.01.10 |       hecd8cb5_0         121 KB
#     certifi-2022.12.7          |   py39hecd8cb5_0         151 KB
#     dash-2.7.0                 |   py39hecd8cb5_0         6.4 MB
#     flask-compress-1.13        |   py39hecd8cb5_0          20 KB
#     numpy-1.21.5               |   py39h2e5f0a9_3          11 KB
#     numpy-base-1.21.5          |   py39h3b1a694_3         4.7 MB
#     openssl-1.1.1t             |       hca72f7f_0         3.3 MB
#     plotly-5.9.0               |   py39hecd8cb5_0         4.1 MB
#     scipy-1.7.3                |   py39h8c7af03_0        15.8 MB
#     tenacity-8.0.1             |   py39hecd8cb5_1          34 KB
#     ------------------------------------------------------------
#                                            Total:        35.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      pkgs/main/osx-64::brotli-python-1.0.9-py39he9d5cce_7 None
#   dash               pkgs/main/osx-64::dash-2.7.0-py39hecd8cb5_0 None
#   flask-compress     pkgs/main/osx-64::flask-compress-1.13-py39hecd8cb5_0 None
#   numpy-base         pkgs/main/osx-64::numpy-base-1.21.5-py39h3b1a694_3 None
#   plotly             pkgs/main/osx-64::plotly-5.9.0-py39hecd8cb5_0 None
#   scikit-learn       pkgs/main/osx-64::scikit-learn-1.1.1-py39he9d5cce_0 None
#   scipy              pkgs/main/osx-64::scipy-1.7.3-py39h8c7af03_0 None
#   tenacity           pkgs/main/osx-64::tenacity-8.0.1-py39hecd8cb5_1 None
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.10.11-hecd8cb5_0 --> 2023.01.10-hecd8cb5_0 None
#   certifi                          2022.9.24-py39hecd8cb5_0 --> 2022.12.7-py39hecd8cb5_0 None
#   numpy                               1.20.3-py39h4b4dc7a_0 --> 1.21.5-py39h2e5f0a9_3 None
#   openssl                                 1.1.1q-hca72f7f_0 --> 1.1.1t-hca72f7f_0 None
#
#
#
# Downloading and Extracting Packages
# scipy-1.7.3          | 15.8 MB   | ##################################### | 100%
# numpy-1.21.5         | 11 KB     | ##################################### | 100%
# certifi-2022.12.7    | 151 KB    | ##################################### | 100%
# plotly-5.9.0         | 4.1 MB    | ##################################### | 100%
# tenacity-8.0.1       | 34 KB     | ##################################### | 100%
# openssl-1.1.1t       | 3.3 MB    | ##################################### | 100%
# brotli-python-1.0.9  | 354 KB    | ##################################### | 100%
# dash-2.7.0           | 6.4 MB    | ##################################### | 100%
# numpy-base-1.21.5    | 4.7 MB    | ##################################### | 100%
# flask-compress-1.13  | 20 KB     | ##################################### | 100%
# ca-certificates-2023 | 121 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: /
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# ERROR conda.core.link:_execute(733): An error occurred while installing package 'defaults::numpy-base-1.21.5-py39h3b1a694_3'.
# Rolling back transaction: done
#
# [Errno 13] Permission denied: '/Users/shenxingyu/opt/anaconda3/lib/python3.9/site-packages/numpy/typing/tests/data/misc/__pycache__'
# ()
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
app = dash.Dash()
app.layout = html.H1('Word Cloud')

#abstract_string.txt
text = open('abstract_string.txt').read()

wordcloud = WordCloud().generate(text)
#show it on html
plt.imshow(wordcloud, interpolation='bilinear')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ts/yc6c7tl96hjdf33yyy_9y96m0000gn/T/ipykernel_37522/2363105389.py in <module>
#       5 text = open('abstract_string.txt').read()
#       6
# ----> 7 wordcloud = WordCloud().generate(text)
#       8 #show it on html
#       9 plt.imshow(wordcloud, interpolation='bilinear')
#
# NameError: name 'WordCloud' is not defined

# %%
import dash.dependencies as dd
import dash_core_components as dcc
import dash_html_components as html

from io import BytesIO

import pandas as pd
from wordcloud import WordCloud
import base64


app = dash.Dash(__name__) #, external_stylesheets=external_stylesheets)

dfm = pd.DataFrame({'word': ['apple', 'pear', 'orange'], 'freq': [1,3,9]})

app.layout = html.Div([
    html.Img(id="image_wc"),
])

def plot_wordcloud(data):
    d = {a: x for a, x in data.values}
    wc = WordCloud(background_color='black', width=480, height=360)
    wc.fit_words(d)
    return wc.to_image()

@app.callback(dd.Output('image_wc', 'src'), [dd.Input('image_wc', 'id')])
def make_image(b):
    img = BytesIO()
    plot_wordcloud(data=dfm).save(img, format='PNG')
    return 'data:image/png;base64,{}'.format(base64.b64encode(img.getvalue()).decode())

if __name__ == '__main__':
    app.run_server(debug=True)
